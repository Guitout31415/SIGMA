# %%
import scanpy as sc
import seaborn as sns
import anndata as ad
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# # Load merge

# %%
adata = sc.read_h5ad("/home/lemgui01/SIGMA/results_mk_human/merge.h5ad")

sc.tl.pca(adata)
sc.pp.neighbors(adata)
sc.tl.umap(adata)

# %%
plt.hist(adata.obs["score"], bins=100)
plt.show()

# %%
sc.pl.umap(adata, color=["score"], cmap="viridis", size=50)

# adata[adata.obs["score"] >= 0.9,]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 14994 × 15103
#     obs: 'sex', 'age', 'disease', 'tissue', 'donor_id', 'cell', 'proba_target', 'score', 'proba_exclu', 'study'
#     uns: 'pca', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'log1p', 'raw'
#     obsp: 'distances', 'connectivities'

# %%
mk = adata[adata.obs["score"] >= 0.9,]

sc.tl.pca(mk)
sc.pp.neighbors(mk)
sc.tl.umap(mk)

sc.pl.umap(mk, color=["sex","age","tissue","disease"], size=150, ncols=2)
# Out:
# /home/lemgui01/.miniconda3/envs/SIGMA/lib/python3.10/site-packages/scanpy/preprocessing/_pca/__init__.py:379: ImplicitModificationWarning: Setting element `.obsm['X_pca']` of view, initializing view as actual.
#   adata.obsm[key_obsm] = X_pca
